# %% [markdown]
# ## List Notes & Practice
# ### Steps to Create Env & ipynb (python notebook)
# 1.  Create project folder
# 2.  Open project folder in VSC
# 3.  Verify your explorer tab and terminal are in the right place
#     *** NO NESTED REPOSITORIES OR PROJECTS ***
# 4.  (optional) initialize repo if pushing to github
# 5.  To create virtual env
#     - in terminal run: `python3 -m venv .venv`
#     *** If it fails, delete and run again ***
# 6.  Create `.gitignore` file at the ROOT of the project (next to the .venv, NOT IN)
# 7.  Document `.venv/` inside `.gitignore`
# 8.  Activate env
#     -   In terminal: `source .venv/Scripts/activate`
#     -   In terminal: `source .venv/bin/activate`
# 8.  Install ipykernel
#     -   In terminal: `pip install ipykernel`
# 9.  Create `.ipynb` file
# 10. Select Kernel (top right of ipynb file once open)
#     -   select the env you created (should be reccommended with a star)

# %% [markdown]
# ### Data Collections
#
# - **Lists (arrays)** - indexed collection. Have order and stay in order. Numbered. `[]`
# - **Dictionaries (dict)** - key/value collection. Have no order. Use a key to access information. `{}`
# - **Tuples** - records (rows of a table). `()`

# %% [markdown]
# ### Strings
# - Collection of single characters.
# - Data access within lists and string is IDENTICAL
# - Index numbers to access values

# %%
greet = 'Hello, World'

#print the first value in a string
print(greet[0])
print(greet[1])
print(greet[2])

# %% [markdown]
# #### Python Indexing operator
# - can be used with strings and lists
# - `[ start : stop : step ]`
# - by default, if we dont include the step, its 1

# %%
print(greet[0:5]) 
print(greet[::-1]) #goes backwards
print(greet[0::2]) # stars at 0, goes to the end
# Out:
# Hello

# %% [markdown]
# ### Type() Function
# -tells us what data type a variable is
# -type(value) -> data type

# %%
print(type(greet))
print(type(13))
print(type(True))
print(type(13.2))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>

# %% [markdown]
# ### Typecasting Function (to change the data type of)
# - str() - turns anything into a string
# - float() - turns value into a float if possible
# - int() - turns value into int if possible

# %%
age = '30'
print(type(age))

# If you permanently want to change a variable you have to re-assign it
age = int(age)

print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# ### len() - returns the length of a string or list
#
# - `len(arg) -> int`
# - works with:
#     - strings
#     - lists
#     - dictionaries
#     - tuples

# %%
print(len(greet))
# Out:
# 12

# %% [markdown]
# #### Methods - built in functions to python objects (everything in python is technically an object), for different datatypes/objects/modules
#
# - functions that are connected to variables of every type
# - defined with a period at the end of a variable name, followed by the method
# - end with parentheses to invoke (run, execute) the method (function)

# %%
print(greet.upper())
print(greet.split())
# Out:
# HELLO, WORLD
# ['Hello,', 'World']

# %% [markdown]
# ### Lists - indexed collections
#
# - Numbered indexes
# - Start counting at 0
# - Any data type can be in a list
# - A list can be made of multiple different data types
# - No-fixed length (mutable - it can be changed)
# - syntax - `[ ]` with comma separated values

# %%
people = ['Carolyn', 'Joe', 'Dylan', 'Akorede']

# %%
print(people[0:])
print(len(people))
# Out:
# ['Carolyn', 'Joe', 'Dylan', 'Akorede']
# 4

# %%
fun = []

# while True:
#     ans = input('Give me a number')
#     fun.append(ans)

#     if(ans == '100'):
#         break

print(fun) # prints things to the terminal/log
# Out:
# []

# %% [markdown]
# ### Types of Error:
#
# - `IndexError` - out of range
# - `TypeError` - wrong type in a list index, wrong type in an operation
# - `SyntaxError` - cant understand code structure, incorrect code grammer
# - `NameError` - Variable/function is not defined
# - `ValueError` - Correct type, invalid value
# - `KeyError` - Dictionary Key that doesnt exist
# - `AttributeError` - Object doesnt have the atribute/method you are trying to use
# - `IndentationError` - Incorrect Indentation
# - `UnboundLocalError` - Trying to access a variable before assignment
# - `FileNotFoundError`
# - `ImportError`
# - `ModuleNotError`

# %% [markdown]
# ### Modifying Lists

# %%
animals = ['Emu', 'Chipmunk', 'Buffalo', 'Dragon']
print(animals)

animals[1] = 'Squirrel'

print(animals)

# %%
# .append() - add 1 element to the end of a list
# .prepend() - add 1 item to the beginning
# .extend() - add multiple items to the end of a list
# .insert() - add items to a specified index of a list
